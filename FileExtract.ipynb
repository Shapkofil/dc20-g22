# %%
import zipfile
import fnmatch

# specify the path to the zip file
zip_path = "C:/Users/izzfa/Documents/Data Science/Year 2/Y2Q4/DC2/2017-04.zip"

# pattern for files to extract
pattern1 = "*metropolitan-street.csv"
pattern2 = "*metropolitan-outcomes.csv"
pattern3 = "*metropolitan-stop-and-search.csv"

# open the zip file for reading
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    
    # iterate through all files in the archive
    for file_name in zip_ref.namelist():
        # print(file_name)
        # extract file if it matches the pattern
        if fnmatch.fnmatch(file_name, pattern1) or fnmatch.fnmatch(file_name, pattern2) or fnmatch.fnmatch(file_name, pattern3):
            # print(file_name)

            #Location of file here
            zip_ref.extract(file_name, "C:/Users/izzfa/Documents/Data Science/Year 2/Y2Q4/DC2/2010-2017")

# %%
import os
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# specify the directory containing the CSV files
directory = "C:/Users/izzfa/Documents/Data Science/Year 2/Y2Q4/DC2/"

# initialize an empty list to store dataframes
df_list = []

# iterate through all subfolders and CSV files in the directory
for root, dirs, files in os.walk(directory):
    for filename in files:
        # print(filename)
        #Change csv names
        if filename.endswith("metropolitan-street.csv"): 
            # print(filename)
            # read the CSV file into a dataframe and append to the list
            filepath = os.path.join(root, filename)
            df = pd.read_csv(filepath)
            df_list.append(df)

# concatenate all dataframes into a single dataframe
concatenated_df = pd.concat(df_list, axis=0, ignore_index=True)
# write the concatenated dataframe to a new parquet file
output_filepath = "C:/Users/izzfa/Documents/Data Science/Year 2/Y2Q4/DC2/Metropolitan-street.parquet"

# write the concatenated dataframe to a Parquet file
table = pa.Table.from_pandas(concatenated_df)
pq.write_table(table, output_filepath)
# Out:
# C:\Users\izzfa\AppData\Local\Temp\ipykernel_21712\332177386.py:24: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   concatenated_df = pd.concat(df_list, axis=0, ignore_index=True)

# %%
filepath_met = "C:/Users/izzfa/Documents/Data Science/Year 2/Y2Q4/DC2/Metropolitan-street.parquet"
filepath_out = "C:/Users/izzfa/Documents/Data Science/Year 2/Y2Q4/DC2/Metropolitan-outcomes.parquet"
filepath_stop = "C:/Users/izzfa/Documents/Data Science/Year 2/Y2Q4/DC2/Metropolitan-stopandsearch.parquet"

# read the Parquet file into a pandas dataframe
df = pq.read_pandas(filepath_met).to_pandas()
df
# Out:
#                               Type                       Date  \
# 0                    Person search  2020-04-30T23:01:00+00:00
# 1                    Person search  2020-04-30T23:01:00+00:00
# 2        Person and Vehicle search  2020-04-30T23:01:00+00:00
# 3        Person and Vehicle search  2020-04-30T23:02:00+00:00
# 4                    Person search  2020-04-30T23:05:00+00:00
# ...                            ...                        ...
# 1523194  Person and Vehicle search  2020-03-31T22:45:00+00:00
# 1523195              Person search  2020-03-31T22:51:00+00:00
# 1523196  Person and Vehicle search  2020-03-31T22:55:00+00:00
# 1523197  Person and Vehicle search  2020-03-31T22:55:00+00:00
# 1523198              Person search  2020-03-31T22:55:00+00:00
#
#          Part of a policing operation  Policing operation   Latitude  \
# 0                                 0.0                 NaN  51.367405
# 1                                 0.0                 NaN  51.495307
# 2                                 0.0                 NaN  51.545923
# 3                                 0.0                 NaN  51.464974
# 4                                 0.0                 NaN        NaN
# ...                               ...                 ...        ...
# 1523194                           0.0                 NaN  51.522310
# 1523195                           0.0                 NaN  51.519859
# 1523196                           0.0                 NaN  51.526825
# 1523197                           0.0                 NaN  51.398988
# 1523198                           0.0                 NaN  51.526825
#
#          Longitude  Gender Age range  \
# 0        -0.178765    Male     25-34
# 1        -0.131908    Male      None
# 2        -0.112096    Male     18-24
# 3        -0.130152    Male   over 34
# 4              NaN    Male      None
# ...            ...     ...       ...
# 1523194   0.054229    Male     18-24
# 1523195  -0.225344    Male   over 34
# 1523196  -0.400848  Female   over 34
# 1523197  -0.250828    Male     18-24
# 1523198  -0.400848    Male     25-34
#
#                                    Self-defined ethnicity  \
# 0                         Other ethnic group - Not stated
# 1                         Other ethnic group - Not stated
# 2                         Other ethnic group - Not stated
# 3                      White - Any other White background
# 4                      White - Any other White background
# ...                                                   ...
# 1523194  Asian/Asian British - Any other Asian background
# 1523195                White - Any other White background
# 1523196       Other ethnic group - Any other ethnic group
# 1523197  Asian/Asian British - Any other Asian background
# 1523198                   Other ethnic group - Not stated
#
#         Officer-defined ethnicity  \
# 0                           White
# 1                           Black
# 2                           Black
# 3                           White
# 4                           White
# ...                           ...
# 1523194                     Asian
# 1523195                     White
# 1523196                     White
# 1523197                     Asian
# 1523198                     Asian
#
#                                                Legislation  \
# 0        Police and Criminal Evidence Act 1984 (section 1)
# 1                    Misuse of Drugs Act 1971 (section 23)
# 2        Police and Criminal Evidence Act 1984 (section 1)
# 3                    Misuse of Drugs Act 1971 (section 23)
# 4                    Misuse of Drugs Act 1971 (section 23)
# ...                                                    ...
# 1523194              Misuse of Drugs Act 1971 (section 23)
# 1523195  Police and Criminal Evidence Act 1984 (section 1)
# 1523196              Misuse of Drugs Act 1971 (section 23)
# 1523197              Misuse of Drugs Act 1971 (section 23)
# 1523198              Misuse of Drugs Act 1971 (section 23)
#
#                            Object of search                       Outcome  \
# 0                              Stolen goods  A no further action disposal
# 1                          Controlled drugs  A no further action disposal
# 2                         Offensive weapons  A no further action disposal
# 3                          Controlled drugs  A no further action disposal
# 4                          Controlled drugs  A no further action disposal
# ...                                     ...                           ...
# 1523194                    Controlled drugs  A no further action disposal
# 1523195  Evidence of offences under the Act  A no further action disposal
# 1523196                    Controlled drugs  A no further action disposal
# 1523197                    Controlled drugs  A no further action disposal
# 1523198                    Controlled drugs  A no further action disposal
#
#          Outcome linked to object of search  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1523194                                 NaN
# 1523195                                 NaN
# 1523196                                 NaN
# 1523197                                 NaN
# 1523198                                 NaN
#
#          Removal of more than just outer clothing
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 1523194                                       NaN
# 1523195                                       NaN
# 1523196                                       NaN
# 1523197                                       NaN
# 1523198                                       NaN
#
# [1523199 rows x 15 columns]
