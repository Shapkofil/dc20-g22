# 2509       Burglary  Investigation complete; no suspect identified      NaN
# 2532       Burglary  Investigation complete; no suspect identified      NaN
# 2666       Burglary  Investigation complete; no suspect identified      NaN
# 2667       Burglary  Investigation complete; no suspect identified      NaN
# ...             ...                                            ...      ...
# 13064414   Burglary                            Under investigation      NaN
# 13064415   Burglary  Investigation complete; no suspect identified      NaN
# 13064416   Burglary  Investigation complete; no suspect identified      NaN
# 13064417   Burglary                            Under investigation      NaN
# 13064418   Burglary                            Under investigation      NaN
#
# [44138 rows x 12 columns]

# %%
wards_csv = pd.read_csv("use_data/LSOAtoWard.csv")
wards_relevant = wards_csv[['LSOA01NM', 'WD11NM']]
merged_df = pd.merge(left=barnetBur_df, right=wards_relevant, left_on='LSOA name', right_on='LSOA01NM')
merged_df.head()
# Out:
#                                             Crime ID    Month  \
# 0  48d7fae1e76d275cfecabf17efbf6fecf769966089dcae...  2020-05
# 1  d1d37e3e233d650abaf3eae1d6585e33f706cebe857ffc...  2020-05
# 2  6b13c905e40eccf73feec600e87a6c70e0667b10980e95...  2020-07
# 3  9869e99b7803ce398498332b862347626619671258ecdb...  2021-01
# 4  83c73a8dfb5749e2f3922ff87ae87e3f0422e3cd8c88fa...  2021-01
#
#                    Reported by                 Falls within  Longitude  \
# 0  Metropolitan Police Service  Metropolitan Police Service  -0.205163
# 1  Metropolitan Police Service  Metropolitan Police Service  -0.203868
# 2  Metropolitan Police Service  Metropolitan Police Service  -0.207839
# 3  Metropolitan Police Service  Metropolitan Police Service  -0.205204
# 4  Metropolitan Police Service  Metropolitan Police Service  -0.203575
#
#     Latitude                   Location  LSOA code    LSOA name Crime type  \
# 0  51.655067  On or near Salisbury Road  E01000248  Barnet 001A   Burglary
# 1  51.653824    On or near Union Street  E01000248  Barnet 001A   Burglary
# 2  51.654289      On or near The Avenue  E01000248  Barnet 001A   Burglary
# 3  51.656578  On or near Strafford Road  E01000248  Barnet 001A   Burglary
# 4  51.655735   On or near Shopping Area  E01000248  Barnet 001A   Burglary
#
#                            Last outcome category  Context     LSOA01NM  \
# 0  Investigation complete; no suspect identified      NaN  Barnet 001A
# 1  Investigation complete; no suspect identified      NaN  Barnet 001A
# 2  Investigation complete; no suspect identified      NaN  Barnet 001A
# 3  Investigation complete; no suspect identified      NaN  Barnet 001A
# 4  Investigation complete; no suspect identified      NaN  Barnet 001A
#
#         WD11NM
# 0  High Barnet
# 1  High Barnet
# 2  High Barnet
# 3  High Barnet
# 4  High Barnet

# %%
df_crimes = merged_df[["Month", "Crime ID","WD11NM"]].copy()
df_crimes= df_crimes.groupby(["WD11NM","Month"]).count()
df_crimes["2Months"]=df_crimes['Crime ID'].shift(1, fill_value=0).add(df_crimes['Crime ID'].shift(2, fill_value=0))
df_crimes["2MonthsLag"] = df_crimes['Crime ID'].shift(3, fill_value=0).add(df_crimes['Crime ID'].shift(4, fill_value=0))
df_crimes["4Months"]=df_crimes['Crime ID'].shift(1, fill_value=0).add(df_crimes['Crime ID'].shift(2, fill_value=0)).add(df_crimes['Crime ID'].shift(3, fill_value=0)).add(df_crimes['Crime ID'].shift(4, fill_value=0))
df_crimes["4MonthsLag"]=df_crimes['Crime ID'].shift(5, fill_value=0).add(df_crimes['Crime ID'].shift(6, fill_value=0)).add(df_crimes['Crime ID'].shift(7, fill_value=0)).add(df_crimes['Crime ID'].shift(8, fill_value=0))
df_crimes['12Months'] = df_crimes['Crime ID'].rolling(window=12).sum().shift(1)
df_crimes[1000:1013]
# Out:
#                        Crime ID  2Months  2MonthsLag  4Months  4MonthsLag  \
# WD11NM        Month
# East Finchley 2020-04         1       23          27       50          43
#               2020-05         7       12          20       32          52
#               2020-06         3        8          23       31          45
#               2020-07         5       10          12       22          54
#               2020-08         5        8           8       16          50
#               2020-09        10       10          10       20          32
#               2020-10        14       15           8       23          31
#               2020-11         8       24          10       34          22
#               2020-12        10       22          15       37          16
#               2021-01        10       18          24       42          20
#               2021-02         7       20          22       42          23
#               2021-03        12       17          18       35          34
#               2021-04        10       19          20       39          37
#
#                        12Months
# WD11NM        Month
# East Finchley 2020-04     128.0
#               2020-05     123.0
#               2020-06     118.0
#               2020-07     113.0
#               2020-08     109.0
#               2020-09     104.0
#               2020-10      99.0
#               2020-11     110.0
#               2020-12     103.0
#               2021-01      94.0
#               2021-02      96.0
#               2021-03      91.0
#               2021-04      92.0

# %%
merged_df = pd.merge(merged_df, df_crimes, on=['Month', 'WD11NM'], how='left')
merged_df
# Out:
#                                               Crime ID_x    Month  \
# 0      48d7fae1e76d275cfecabf17efbf6fecf769966089dcae...  2020-05
# 1      d1d37e3e233d650abaf3eae1d6585e33f706cebe857ffc...  2020-05
# 2      6b13c905e40eccf73feec600e87a6c70e0667b10980e95...  2020-07
# 3      9869e99b7803ce398498332b862347626619671258ecdb...  2021-01
# 4      83c73a8dfb5749e2f3922ff87ae87e3f0422e3cd8c88fa...  2021-01
# ...                                                  ...      ...
# 43637  b1091500e22e9ad0d3a00d7e7a8d9b52834450f89e4d29...  2019-11
# 43638  48f8cdb05b7885d22cb314c6fbf47ac74085cd4ad860a4...  2019-12
# 43639  33dd7b7f6454bfd56f8f88b3a54a5ad27c9709f3701ed2...  2020-01
# 43640  518085b2f72f44065a22b4625b3f4b5093191a44bcff52...  2020-01
# 43641  0715754d17ad3b171638cc6802f385d0a8e2b18f5fd8ff...  2020-02
#
#                        Reported by                 Falls within  Longitude  \
# 0      Metropolitan Police Service  Metropolitan Police Service  -0.205163
# 1      Metropolitan Police Service  Metropolitan Police Service  -0.203868
# 2      Metropolitan Police Service  Metropolitan Police Service  -0.207839
# 3      Metropolitan Police Service  Metropolitan Police Service  -0.205204
# 4      Metropolitan Police Service  Metropolitan Police Service  -0.203575
# ...                            ...                          ...        ...
# 43637  Metropolitan Police Service  Metropolitan Police Service  -0.200203
# 43638  Metropolitan Police Service  Metropolitan Police Service  -0.196775
# 43639  Metropolitan Police Service  Metropolitan Police Service  -0.194423
# 43640  Metropolitan Police Service  Metropolitan Police Service  -0.194423
# 43641  Metropolitan Police Service  Metropolitan Police Service  -0.200128
#
#         Latitude                    Location  LSOA code    LSOA name  \
# 0      51.655067   On or near Salisbury Road  E01000248  Barnet 001A
# 1      51.653824     On or near Union Street  E01000248  Barnet 001A
# 2      51.654289       On or near The Avenue  E01000248  Barnet 001A
# 3      51.656578   On or near Strafford Road  E01000248  Barnet 001A
# 4      51.655735    On or near Shopping Area  E01000248  Barnet 001A
# ...          ...                         ...        ...          ...
# 43637  51.648166  On or near Ellesmere Grove  E01000293  Barnet 001F
# 43638  51.648230  On or near Woodfall Avenue  E01000293  Barnet 001F
# 43639  51.648841       On or near Vale Drive  E01000293  Barnet 001F
# 43640  51.648841       On or near Vale Drive  E01000293  Barnet 001F
# 43641  51.652975      On or near Wood Street  E01000293  Barnet 001F
#
#       Crime type                          Last outcome category  Context  \
# 0       Burglary  Investigation complete; no suspect identified      NaN
# 1       Burglary  Investigation complete; no suspect identified      NaN
# 2       Burglary  Investigation complete; no suspect identified      NaN
# 3       Burglary  Investigation complete; no suspect identified      NaN
# 4       Burglary  Investigation complete; no suspect identified      NaN
# ...          ...                                            ...      ...
# 43637   Burglary                      Status update unavailable      NaN
# 43638   Burglary                            Under investigation      NaN
# 43639   Burglary  Investigation complete; no suspect identified      NaN
# 43640   Burglary  Investigation complete; no suspect identified      NaN
# 43641   Burglary  Investigation complete; no suspect identified      NaN
#
#           LSOA01NM       WD11NM  Crime ID_y  2Months  2MonthsLag  4Months  \
# 0      Barnet 001A  High Barnet           7       15          21       36
# 1      Barnet 001A  High Barnet           7       15          21       36
# 2      Barnet 001A  High Barnet           6       17          15       32
# 3      Barnet 001A  High Barnet          10       16          28       44
# 4      Barnet 001A  High Barnet          10       16          28       44
# ...            ...          ...         ...      ...         ...      ...
# 43637  Barnet 001F    Underhill           8       22          13       35
# 43638  Barnet 001F    Underhill          15       23          13       36
# 43639  Barnet 001F    Underhill          16       23          22       45
# 43640  Barnet 001F    Underhill          16       23          22       45
# 43641  Barnet 001F    Underhill          12       31          23       54
#
#        4MonthsLag  12Months
# 0              59     161.0
# 1              59     161.0
# 2              48     137.0
# 3              38     118.0
# 4              38     118.0
# ...           ...       ...
# 43637          55     165.0
# 43638          43     153.0
# 43639          32     153.0
# 43640          32     153.0
# 43641          31     154.0
#
# [43642 rows x 20 columns]
